# %% [markdown]
# LSTM

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt

# Function to retrieve data for a given symbol with only open and close prices
def get_stock_data(symbol, start_date, end_date):
    try:
        data = yf.download(symbol, start=start_date, end=end_date)[['Open', 'Close']]
        return data
    except Exception as e:
        print(f"Failed to download data for {symbol}: {e}")
        return None

# Function to preprocess data and split into training and testing sets
def preprocess_data(data, train_percentage=0.8):
    if data is None or data.empty:
        return None, None, None

    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data)

    train_size = int(len(scaled_data) * train_percentage)
    if train_size == 0:
        return None, None, None

    train_data = scaled_data[:train_size]
    test_data = scaled_data[train_size:]

    return train_data, test_data, scaler

# Function to create LSTM model with refined architecture
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(units=8, input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(units=2))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Function to train LSTM model with adjusted epochs and batch size for higher accuracy
def train_model(model, X_train, y_train):
    model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=2)

# Function to evaluate model performance
def evaluate_model(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    accuracy = r2_score(y_true, y_pred)
    return mse, accuracy

# Function to plot predicted vs actual prices for a stock
def plot_predictions(symbol, actual_prices, predicted_prices, dates, scaler):
    actual_prices = scaler.inverse_transform(actual_prices)
    predicted_prices = scaler.inverse_transform(predicted_prices)

    plt.figure(figsize=(16, 8))
    plt.plot(dates, actual_prices[:, 1], label='Actual Close Prices')
    plt.plot(dates, predicted_prices[:, 1], label='Predicted Close Prices')
    plt.title(f"Actual vs Predicted Close Prices for {symbol}")
    plt.xlabel("Date")
    plt.ylabel("Close Price (INR)")
    plt.xticks(rotation=45)
    plt.legend()
    plt.show()

# Main function with further refined settings for improved accuracy
def main():
    symbols =  ['ICICIBANK.NS', 'AXISBANK.NS', 'SBIN.NS', 'INDUSINDBK.NS', 'FEDERALBNK.NS', 'IDFCFIRSTB.NS', 'PNB.NS', 'BANKBARODA.NS']
    end_date = input("Enter end date (YYYY-MM-DD): ")
    end_date_dt = pd.to_datetime(end_date)
    start_date_dt = pd.to_datetime('2020-01-01')

    results = []

    for symbol in symbols:
        print(f"Processing {symbol}...")
        data = get_stock_data(symbol, start_date=start_date_dt, end_date=end_date)
        if data is None:
            print(f"No data available for {symbol}. Skipping...")
            continue

        train_data, test_data, scaler = preprocess_data(data)
        if train_data is None or test_data is None or scaler is None:
            print(f"Insufficient data for {symbol}. Skipping...")
            continue

        X_train, y_train = train_data[:-1], train_data[1:]
        X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))  # Reshape for LSTM input
        X_test, y_test = test_data[:-1], test_data[1:]
        X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))  # Reshape for LSTM input

        model = create_lstm_model(input_shape=(1, 2))
        train_model(model, X_train, y_train)

        predictions = model.predict(X_test)

        mse, accuracy = evaluate_model(y_test, predictions)

        dates = data.index[-len(predictions):]  # Dates for the test data

        plot_predictions(symbol, test_data[1:], predictions, dates, scaler)

        results.append({
            'Symbol': symbol,
            'Predicted Close Price': scaler.inverse_transform(predictions)[-1][1],
            'Accuracy (%)': accuracy * 100,
            'MSE': mse,
            'R-squared': accuracy
        })
    if results:
        results_df = pd.DataFrame(results)
        print(results_df)

if __name__ == "__main__":
    main()
# Out:
# Enter end date (YYYY-MM-DD): 2025-05-23
# Processing ICICIBANK.NS...
# [*********************100%***********************]  1 of 1 completed
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 34/34 - 2s - 73ms/step - loss: 0.1900
# Epoch 2/100
# 34/34 - 0s - 7ms/step - loss: 0.1367
# Epoch 3/100
# 34/34 - 0s - 4ms/step - loss: 0.0959
# Epoch 4/100
# 34/34 - 0s - 3ms/step - loss: 0.0653
# Epoch 5/100
# 34/34 - 0s - 4ms/step - loss: 0.0441
# Epoch 6/100
# 34/34 - 0s - 4ms/step - loss: 0.0320
# Epoch 7/100
# 34/34 - 0s - 4ms/step - loss: 0.0267
# Epoch 8/100
# 34/34 - 0s - 4ms/step - loss: 0.0228
# Epoch 9/100
# 34/34 - 0s - 4ms/step - loss: 0.0219
# Epoch 10/100
# 34/34 - 0s - 4ms/step - loss: 0.0216
# Epoch 11/100
# 34/34 - 0s - 3ms/step - loss: 0.0202
# Epoch 12/100
# 34/34 - 0s - 3ms/step - loss: 0.0193
# Epoch 13/100
# 34/34 - 0s - 4ms/step - loss: 0.0180
# Epoch 14/100
# 34/34 - 0s - 4ms/step - loss: 0.0171
# Epoch 15/100
# 34/34 - 0s - 4ms/step - loss: 0.0155
# Epoch 16/100
# 34/34 - 0s - 3ms/step - loss: 0.0145
# Epoch 17/100
# 34/34 - 0s - 4ms/step - loss: 0.0135
# Epoch 18/100
# 34/34 - 0s - 4ms/step - loss: 0.0121
# Epoch 19/100
# 34/34 - 0s - 3ms/step - loss: 0.0110
# Epoch 20/100
# 34/34 - 0s - 3ms/step - loss: 0.0095
# Epoch 21/100
# 34/34 - 0s - 4ms/step - loss: 0.0096
# Epoch 22/100
# 34/34 - 0s - 4ms/step - loss: 0.0088
# Epoch 23/100
# 34/34 - 0s - 4ms/step - loss: 0.0080
# Epoch 24/100
# 34/34 - 0s - 4ms/step - loss: 0.0077
# Epoch 25/100
# 34/34 - 0s - 5ms/step - loss: 0.0068
# Epoch 26/100
# 34/34 - 0s - 3ms/step - loss: 0.0075
# Epoch 27/100
# 34/34 - 0s - 4ms/step - loss: 0.0064
# Epoch 28/100
# 34/34 - 0s - 3ms/step - loss: 0.0061
# Epoch 29/100
# 34/34 - 0s - 3ms/step - loss: 0.0059
# Epoch 30/100
# 34/34 - 0s - 4ms/step - loss: 0.0055
# Epoch 31/100
# 34/34 - 0s - 4ms/step - loss: 0.0060
# Epoch 32/100
# 34/34 - 0s - 4ms/step - loss: 0.0056
# Epoch 33/100
# 34/34 - 0s - 4ms/step - loss: 0.0049
# Epoch 34/100
# 34/34 - 0s - 3ms/step - loss: 0.0047
# Epoch 35/100
# 34/34 - 0s - 4ms/step - loss: 0.0048
# Epoch 36/100
# 34/34 - 0s - 4ms/step - loss: 0.0048
# Epoch 37/100
# 34/34 - 0s - 4ms/step - loss: 0.0043
# Epoch 38/100
# 34/34 - 0s - 4ms/step - loss: 0.0044
# Epoch 39/100
# 34/34 - 0s - 4ms/step - loss: 0.0045
# Epoch 40/100
# 34/34 - 0s - 4ms/step - loss: 0.0045
# Epoch 41/100
# 34/34 - 0s - 4ms/step - loss: 0.0046
# Epoch 42/100
# 34/34 - 0s - 4ms/step - loss: 0.0044
# Epoch 43/100
# 34/34 - 0s - 4ms/step - loss: 0.0039
# Epoch 44/100
# 34/34 - 0s - 4ms/step - loss: 0.0036
# Epoch 45/100
# 34/34 - 0s - 3ms/step - loss: 0.0039
# Epoch 46/100
# 34/34 - 0s - 4ms/step - loss: 0.0038
# Epoch 47/100
# 34/34 - 0s - 4ms/step - loss: 0.0036
# Epoch 48/100
# 34/34 - 0s - 4ms/step - loss: 0.0035
# Epoch 49/100
# 34/34 - 0s - 4ms/step - loss: 0.0031
# Epoch 50/100
# 34/34 - 0s - 4ms/step - loss: 0.0036
# Epoch 51/100
# 34/34 - 0s - 4ms/step - loss: 0.0041
# Epoch 52/100
# 34/34 - 0s - 4ms/step - loss: 0.0035
# Epoch 53/100
# 34/34 - 0s - 4ms/step - loss: 0.0033
# Epoch 54/100
# 34/34 - 0s - 4ms/step - loss: 0.0032
# Epoch 55/100
# 34/34 - 0s - 4ms/step - loss: 0.0034
# Epoch 56/100
# 34/34 - 0s - 4ms/step - loss: 0.0032
# Epoch 57/100
# 34/34 - 0s - 4ms/step - loss: 0.0032
# Epoch 58/100
# 34/34 - 0s - 4ms/step - loss: 0.0031
# Epoch 59/100
# 34/34 - 0s - 3ms/step - loss: 0.0029
# Epoch 60/100
# 34/34 - 0s - 4ms/step - loss: 0.0026
# Epoch 61/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 62/100
# 34/34 - 0s - 6ms/step - loss: 0.0029
# Epoch 63/100
# 34/34 - 0s - 6ms/step - loss: 0.0029
# Epoch 64/100
# 34/34 - 0s - 6ms/step - loss: 0.0030
# Epoch 65/100
# 34/34 - 0s - 9ms/step - loss: 0.0029
# Epoch 66/100
# 34/34 - 0s - 9ms/step - loss: 0.0026
# Epoch 67/100
# 34/34 - 0s - 5ms/step - loss: 0.0030
# Epoch 68/100
# 34/34 - 0s - 9ms/step - loss: 0.0026
# Epoch 69/100
# 34/34 - 0s - 9ms/step - loss: 0.0027
# Epoch 70/100
# 34/34 - 0s - 9ms/step - loss: 0.0025
# Epoch 71/100
# 34/34 - 0s - 7ms/step - loss: 0.0026
# Epoch 72/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 73/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 74/100
# 34/34 - 0s - 3ms/step - loss: 0.0026
# Epoch 75/100
# 34/34 - 0s - 3ms/step - loss: 0.0026
# Epoch 76/100
# 34/34 - 0s - 3ms/step - loss: 0.0026
# Epoch 77/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 78/100
# 34/34 - 0s - 3ms/step - loss: 0.0025
# Epoch 79/100
# 34/34 - 0s - 5ms/step - loss: 0.0024
# Epoch 80/100
# 34/34 - 0s - 4ms/step - loss: 0.0022
# Epoch 81/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 82/100
# 34/34 - 0s - 4ms/step - loss: 0.0026
# Epoch 83/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 84/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 85/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 86/100
# 34/34 - 0s - 4ms/step - loss: 0.0022
# Epoch 87/100
# 34/34 - 0s - 8ms/step - loss: 0.0025
# Epoch 88/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 89/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 90/100
# 34/34 - 0s - 3ms/step - loss: 0.0021
# Epoch 91/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 92/100
# 34/34 - 0s - 3ms/step - loss: 0.0020
# Epoch 93/100
# 34/34 - 0s - 5ms/step - loss: 0.0024
# Epoch 94/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 95/100
# 34/34 - 0s - 4ms/step - loss: 0.0022
# Epoch 96/100
# 34/34 - 0s - 3ms/step - loss: 0.0021
# Epoch 97/100
# 34/34 - 0s - 3ms/step - loss: 0.0023
# Epoch 98/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 99/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 100/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Processing AXISBANK.NS...
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 - 2s - 71ms/step - loss: 0.1914
# Epoch 2/100
# 34/34 - 0s - 3ms/step - loss: 0.1408
# Epoch 3/100
# 34/34 - 0s - 4ms/step - loss: 0.0939
# Epoch 4/100
# 34/34 - 0s - 4ms/step - loss: 0.0562
# Epoch 5/100
# 34/34 - 0s - 4ms/step - loss: 0.0315
# Epoch 6/100
# 34/34 - 0s - 8ms/step - loss: 0.0228
# Epoch 7/100
# 34/34 - 0s - 4ms/step - loss: 0.0205
# Epoch 8/100
# 34/34 - 0s - 3ms/step - loss: 0.0187
# Epoch 9/100
# 34/34 - 0s - 4ms/step - loss: 0.0186
# Epoch 10/100
# 34/34 - 0s - 4ms/step - loss: 0.0174
# Epoch 11/100
# 34/34 - 0s - 4ms/step - loss: 0.0180
# Epoch 12/100
# 34/34 - 0s - 4ms/step - loss: 0.0150
# Epoch 13/100
# 34/34 - 0s - 4ms/step - loss: 0.0145
# Epoch 14/100
# 34/34 - 0s - 4ms/step - loss: 0.0140
# Epoch 15/100
# 34/34 - 0s - 4ms/step - loss: 0.0117
# Epoch 16/100
# 34/34 - 0s - 6ms/step - loss: 0.0119
# Epoch 17/100
# 34/34 - 0s - 9ms/step - loss: 0.0128
# Epoch 18/100
# 34/34 - 0s - 8ms/step - loss: 0.0097
# Epoch 19/100
# 34/34 - 0s - 9ms/step - loss: 0.0102
# Epoch 20/100
# 34/34 - 0s - 9ms/step - loss: 0.0090
# Epoch 21/100
# 34/34 - 0s - 10ms/step - loss: 0.0087
# Epoch 22/100
# 34/34 - 0s - 5ms/step - loss: 0.0082
# Epoch 23/100
# 34/34 - 0s - 6ms/step - loss: 0.0075
# Epoch 24/100
# 34/34 - 0s - 7ms/step - loss: 0.0082
# Epoch 25/100
# 34/34 - 0s - 6ms/step - loss: 0.0075
# Epoch 26/100
# 34/34 - 0s - 4ms/step - loss: 0.0069
# Epoch 27/100
# 34/34 - 0s - 4ms/step - loss: 0.0067
# Epoch 28/100
# 34/34 - 0s - 4ms/step - loss: 0.0062
# Epoch 29/100
# 34/34 - 0s - 4ms/step - loss: 0.0061
# Epoch 30/100
# 34/34 - 0s - 4ms/step - loss: 0.0059
# Epoch 31/100
# 34/34 - 0s - 4ms/step - loss: 0.0056
# Epoch 32/100
# 34/34 - 0s - 4ms/step - loss: 0.0055
# Epoch 33/100
# 34/34 - 0s - 4ms/step - loss: 0.0056
# Epoch 34/100
# 34/34 - 0s - 4ms/step - loss: 0.0052
# Epoch 35/100
# 34/34 - 0s - 4ms/step - loss: 0.0048
# Epoch 36/100
# 34/34 - 0s - 4ms/step - loss: 0.0051
# Epoch 37/100
# 34/34 - 0s - 4ms/step - loss: 0.0050
# Epoch 38/100
# 34/34 - 0s - 4ms/step - loss: 0.0047
# Epoch 39/100
# 34/34 - 0s - 4ms/step - loss: 0.0051
# Epoch 40/100
# 34/34 - 0s - 4ms/step - loss: 0.0048
# Epoch 41/100
# 34/34 - 0s - 4ms/step - loss: 0.0044
# Epoch 42/100
# 34/34 - 0s - 4ms/step - loss: 0.0045
# Epoch 43/100
# 34/34 - 0s - 4ms/step - loss: 0.0040
# Epoch 44/100
# 34/34 - 0s - 4ms/step - loss: 0.0041
# Epoch 45/100
# 34/34 - 0s - 4ms/step - loss: 0.0042
# Epoch 46/100
# 34/34 - 0s - 4ms/step - loss: 0.0037
# Epoch 47/100
# 34/34 - 0s - 4ms/step - loss: 0.0042
# Epoch 48/100
# 34/34 - 0s - 4ms/step - loss: 0.0034
# Epoch 49/100
# 34/34 - 0s - 4ms/step - loss: 0.0038
# Epoch 50/100
# 34/34 - 0s - 4ms/step - loss: 0.0037
# Epoch 51/100
# 34/34 - 0s - 4ms/step - loss: 0.0038
# Epoch 52/100
# 34/34 - 0s - 4ms/step - loss: 0.0036
# Epoch 53/100
# 34/34 - 0s - 4ms/step - loss: 0.0031
# Epoch 54/100
# 34/34 - 0s - 4ms/step - loss: 0.0034
# Epoch 55/100
# 34/34 - 0s - 4ms/step - loss: 0.0032
# Epoch 56/100
# 34/34 - 0s - 5ms/step - loss: 0.0032
# Epoch 57/100
# 34/34 - 0s - 8ms/step - loss: 0.0032
# Epoch 58/100
# 34/34 - 0s - 4ms/step - loss: 0.0031
# Epoch 59/100
# 34/34 - 0s - 4ms/step - loss: 0.0031
# Epoch 60/100
# 34/34 - 0s - 4ms/step - loss: 0.0029
# Epoch 61/100
# 34/34 - 0s - 4ms/step - loss: 0.0032
# Epoch 62/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 63/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 64/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 65/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 66/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 67/100
# 34/34 - 0s - 4ms/step - loss: 0.0029
# Epoch 68/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 69/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 70/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 71/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 72/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 73/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 74/100
# 34/34 - 0s - 4ms/step - loss: 0.0022
# Epoch 75/100
# 34/34 - 0s - 4ms/step - loss: 0.0022
# Epoch 76/100
# 34/34 - 0s - 4ms/step - loss: 0.0022
# Epoch 77/100
# 34/34 - 0s - 4ms/step - loss: 0.0022
# Epoch 78/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 79/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 80/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 81/100
# 34/34 - 0s - 4ms/step - loss: 0.0019
# Epoch 82/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 83/100
# 34/34 - 0s - 4ms/step - loss: 0.0017
# Epoch 84/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 85/100
# 34/34 - 0s - 4ms/step - loss: 0.0019
# Epoch 86/100
# 34/34 - 0s - 5ms/step - loss: 0.0019
# Epoch 87/100
# 34/34 - 0s - 4ms/step - loss: 0.0019
# Epoch 88/100
# 34/34 - 0s - 4ms/step - loss: 0.0019
# Epoch 89/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 90/100
# 34/34 - 0s - 5ms/step - loss: 0.0020
# Epoch 91/100
# 34/34 - 0s - 4ms/step - loss: 0.0017
# Epoch 92/100
# 34/34 - 0s - 3ms/step - loss: 0.0019
# Epoch 93/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 94/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 95/100
# 34/34 - 0s - 3ms/step - loss: 0.0016
# Epoch 96/100
# 34/34 - 0s - 9ms/step - loss: 0.0016
# Epoch 97/100
# 34/34 - 0s - 6ms/step - loss: 0.0015
# Epoch 98/100
# 34/34 - 0s - 9ms/step - loss: 0.0016
# Epoch 99/100
# 34/34 - 0s - 9ms/step - loss: 0.0016
# Epoch 100/100
# 34/34 - 0s - 9ms/step - loss: 0.0013
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# Processing SBIN.NS...
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 - 2s - 63ms/step - loss: 0.1404
# Epoch 2/100
# 34/34 - 0s - 8ms/step - loss: 0.0883
# Epoch 3/100
# 34/34 - 0s - 4ms/step - loss: 0.0537
# Epoch 4/100
# 34/34 - 0s - 4ms/step - loss: 0.0332
# Epoch 5/100
# 34/34 - 0s - 4ms/step - loss: 0.0236
# Epoch 6/100
# 34/34 - 0s - 4ms/step - loss: 0.0198
# Epoch 7/100
# 34/34 - 0s - 4ms/step - loss: 0.0173
# Epoch 8/100
# 34/34 - 0s - 4ms/step - loss: 0.0168
# Epoch 9/100
# 34/34 - 0s - 4ms/step - loss: 0.0149
# Epoch 10/100
# 34/34 - 0s - 4ms/step - loss: 0.0145
# Epoch 11/100
# 34/34 - 0s - 4ms/step - loss: 0.0130
# Epoch 12/100
# 34/34 - 0s - 4ms/step - loss: 0.0118
# Epoch 13/100
# 34/34 - 0s - 4ms/step - loss: 0.0116
# Epoch 14/100
# 34/34 - 0s - 4ms/step - loss: 0.0101
# Epoch 15/100
# 34/34 - 0s - 4ms/step - loss: 0.0087
# Epoch 16/100
# 34/34 - 0s - 9ms/step - loss: 0.0093
# Epoch 17/100
# 34/34 - 0s - 4ms/step - loss: 0.0077
# Epoch 18/100
# 34/34 - 0s - 4ms/step - loss: 0.0082
# Epoch 19/100
# 34/34 - 0s - 4ms/step - loss: 0.0068
# Epoch 20/100
# 34/34 - 0s - 4ms/step - loss: 0.0066
# Epoch 21/100
# 34/34 - 0s - 4ms/step - loss: 0.0066
# Epoch 22/100
# 34/34 - 0s - 5ms/step - loss: 0.0062
# Epoch 23/100
# 34/34 - 0s - 4ms/step - loss: 0.0056
# Epoch 24/100
# 34/34 - 0s - 4ms/step - loss: 0.0059
# Epoch 25/100
# 34/34 - 0s - 4ms/step - loss: 0.0059
# Epoch 26/100
# 34/34 - 0s - 4ms/step - loss: 0.0053
# Epoch 27/100
# 34/34 - 0s - 4ms/step - loss: 0.0053
# Epoch 28/100
# 34/34 - 0s - 4ms/step - loss: 0.0050
# Epoch 29/100
# 34/34 - 0s - 5ms/step - loss: 0.0046
# Epoch 30/100
# 34/34 - 0s - 4ms/step - loss: 0.0047
# Epoch 31/100
# 34/34 - 0s - 4ms/step - loss: 0.0049
# Epoch 32/100
# 34/34 - 0s - 4ms/step - loss: 0.0048
# Epoch 33/100
# 34/34 - 0s - 4ms/step - loss: 0.0046
# Epoch 34/100
# 34/34 - 0s - 4ms/step - loss: 0.0038
# Epoch 35/100
# 34/34 - 0s - 4ms/step - loss: 0.0043
# Epoch 36/100
# 34/34 - 0s - 4ms/step - loss: 0.0041
# Epoch 37/100
# 34/34 - 0s - 4ms/step - loss: 0.0038
# Epoch 38/100
# 34/34 - 0s - 4ms/step - loss: 0.0042
# Epoch 39/100
# 34/34 - 0s - 4ms/step - loss: 0.0040
# Epoch 40/100
# 34/34 - 0s - 4ms/step - loss: 0.0041
# Epoch 41/100
# 34/34 - 0s - 4ms/step - loss: 0.0039
# Epoch 42/100
# 34/34 - 0s - 4ms/step - loss: 0.0034
# Epoch 43/100
# 34/34 - 0s - 4ms/step - loss: 0.0042
# Epoch 44/100
# 34/34 - 0s - 5ms/step - loss: 0.0034
# Epoch 45/100
# 34/34 - 0s - 4ms/step - loss: 0.0035
# Epoch 46/100
# 34/34 - 0s - 4ms/step - loss: 0.0035
# Epoch 47/100
# 34/34 - 0s - 4ms/step - loss: 0.0037
# Epoch 48/100
# 34/34 - 0s - 4ms/step - loss: 0.0037
# Epoch 49/100
# 34/34 - 0s - 4ms/step - loss: 0.0033
# Epoch 50/100
# 34/34 - 0s - 4ms/step - loss: 0.0034
# Epoch 51/100
# 34/34 - 0s - 4ms/step - loss: 0.0032
# Epoch 52/100
# 34/34 - 0s - 5ms/step - loss: 0.0031
# Epoch 53/100
# 34/34 - 0s - 9ms/step - loss: 0.0033
# Epoch 54/100
# 34/34 - 0s - 6ms/step - loss: 0.0031
# Epoch 55/100
# 34/34 - 0s - 8ms/step - loss: 0.0029
# Epoch 56/100
# 34/34 - 0s - 9ms/step - loss: 0.0029
# Epoch 57/100
# 34/34 - 0s - 9ms/step - loss: 0.0031
# Epoch 58/100
# 34/34 - 0s - 9ms/step - loss: 0.0030
# Epoch 59/100
# 34/34 - 0s - 9ms/step - loss: 0.0026
# Epoch 60/100
# 34/34 - 0s - 6ms/step - loss: 0.0029
# Epoch 61/100
# 34/34 - 0s - 9ms/step - loss: 0.0028
# Epoch 62/100
# 34/34 - 0s - 8ms/step - loss: 0.0024
# Epoch 63/100
# 34/34 - 0s - 4ms/step - loss: 0.0029
# Epoch 64/100
# 34/34 - 0s - 5ms/step - loss: 0.0027
# Epoch 65/100
# 34/34 - 0s - 8ms/step - loss: 0.0027
# Epoch 66/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 67/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 68/100
# 34/34 - 0s - 3ms/step - loss: 0.0023
# Epoch 69/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 70/100
# 34/34 - 0s - 5ms/step - loss: 0.0023
# Epoch 71/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 72/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 73/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 74/100
# 34/34 - 0s - 4ms/step - loss: 0.0026
# Epoch 75/100
# 34/34 - 0s - 4ms/step - loss: 0.0022
# Epoch 76/100
# 34/34 - 0s - 7ms/step - loss: 0.0024
# Epoch 77/100
# 34/34 - 0s - 10ms/step - loss: 0.0023
# Epoch 78/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 79/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 80/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 81/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 82/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 83/100
# 34/34 - 0s - 5ms/step - loss: 0.0020
# Epoch 84/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 85/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 86/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 87/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 88/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 89/100
# 34/34 - 0s - 4ms/step - loss: 0.0019
# Epoch 90/100
# 34/34 - 0s - 4ms/step - loss: 0.0019
# Epoch 91/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 92/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 93/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 94/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 95/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 96/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 97/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 98/100
# 34/34 - 0s - 5ms/step - loss: 0.0018
# Epoch 99/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 100/100
# 34/34 - 0s - 4ms/step - loss: 0.0019
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Processing INDUSINDBK.NS...
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 - 2s - 63ms/step - loss: 0.2548
# Epoch 2/100
# 34/34 - 0s - 4ms/step - loss: 0.1780
# Epoch 3/100
# 34/34 - 0s - 4ms/step - loss: 0.1109
# Epoch 4/100
# 34/34 - 0s - 4ms/step - loss: 0.0665
# Epoch 5/100
# 34/34 - 0s - 4ms/step - loss: 0.0369
# Epoch 6/100
# 34/34 - 0s - 11ms/step - loss: 0.0256
# Epoch 7/100
# 34/34 - 0s - 9ms/step - loss: 0.0227
# Epoch 8/100
# 34/34 - 0s - 9ms/step - loss: 0.0203
# Epoch 9/100
# 34/34 - 0s - 8ms/step - loss: 0.0198
# Epoch 10/100
# 34/34 - 0s - 10ms/step - loss: 0.0182
# Epoch 11/100
# 34/34 - 0s - 9ms/step - loss: 0.0183
# Epoch 12/100
# 34/34 - 0s - 9ms/step - loss: 0.0176
# Epoch 13/100
# 34/34 - 0s - 7ms/step - loss: 0.0173
# Epoch 14/100
# 34/34 - 0s - 4ms/step - loss: 0.0168
# Epoch 15/100
# 34/34 - 0s - 4ms/step - loss: 0.0160
# Epoch 16/100
# 34/34 - 0s - 4ms/step - loss: 0.0143
# Epoch 17/100
# 34/34 - 0s - 4ms/step - loss: 0.0126
# Epoch 18/100
# 34/34 - 0s - 4ms/step - loss: 0.0127
# Epoch 19/100
# 34/34 - 0s - 4ms/step - loss: 0.0124
# Epoch 20/100
# 34/34 - 0s - 4ms/step - loss: 0.0113
# Epoch 21/100
# 34/34 - 0s - 4ms/step - loss: 0.0108
# Epoch 22/100
# 34/34 - 0s - 4ms/step - loss: 0.0105
# Epoch 23/100
# 34/34 - 0s - 4ms/step - loss: 0.0104
# Epoch 24/100
# 34/34 - 0s - 4ms/step - loss: 0.0093
# Epoch 25/100
# 34/34 - 0s - 4ms/step - loss: 0.0089
# Epoch 26/100
# 34/34 - 0s - 4ms/step - loss: 0.0085
# Epoch 27/100
# 34/34 - 0s - 4ms/step - loss: 0.0079
# Epoch 28/100
# 34/34 - 0s - 4ms/step - loss: 0.0081
# Epoch 29/100
# 34/34 - 0s - 4ms/step - loss: 0.0072
# Epoch 30/100
# 34/34 - 0s - 4ms/step - loss: 0.0078
# Epoch 31/100
# 34/34 - 0s - 4ms/step - loss: 0.0075
# Epoch 32/100
# 34/34 - 0s - 4ms/step - loss: 0.0072
# Epoch 33/100
# 34/34 - 0s - 8ms/step - loss: 0.0075
# Epoch 34/100
# 34/34 - 0s - 4ms/step - loss: 0.0072
# Epoch 35/100
# 34/34 - 0s - 4ms/step - loss: 0.0069
# Epoch 36/100
# 34/34 - 0s - 4ms/step - loss: 0.0067
# Epoch 37/100
# 34/34 - 0s - 4ms/step - loss: 0.0076
# Epoch 38/100
# 34/34 - 0s - 5ms/step - loss: 0.0068
# Epoch 39/100
# 34/34 - 0s - 4ms/step - loss: 0.0067
# Epoch 40/100
# 34/34 - 0s - 4ms/step - loss: 0.0069
# Epoch 41/100
# 34/34 - 0s - 4ms/step - loss: 0.0064
# Epoch 42/100
# 34/34 - 0s - 4ms/step - loss: 0.0066
# Epoch 43/100
# 34/34 - 0s - 4ms/step - loss: 0.0055
# Epoch 44/100
# 34/34 - 0s - 4ms/step - loss: 0.0056
# Epoch 45/100
# 34/34 - 0s - 4ms/step - loss: 0.0057
# Epoch 46/100
# 34/34 - 0s - 4ms/step - loss: 0.0061
# Epoch 47/100
# 34/34 - 0s - 4ms/step - loss: 0.0054
# Epoch 48/100
# 34/34 - 0s - 4ms/step - loss: 0.0062
# Epoch 49/100
# 34/34 - 0s - 4ms/step - loss: 0.0059
# Epoch 50/100
# 34/34 - 0s - 4ms/step - loss: 0.0056
# Epoch 51/100
# 34/34 - 0s - 4ms/step - loss: 0.0052
# Epoch 52/100
# 34/34 - 0s - 4ms/step - loss: 0.0052
# Epoch 53/100
# 34/34 - 0s - 4ms/step - loss: 0.0052
# Epoch 54/100
# 34/34 - 0s - 4ms/step - loss: 0.0049
# Epoch 55/100
# 34/34 - 0s - 4ms/step - loss: 0.0056
# Epoch 56/100
# 34/34 - 0s - 4ms/step - loss: 0.0053
# Epoch 57/100
# 34/34 - 0s - 4ms/step - loss: 0.0052
# Epoch 58/100
# 34/34 - 0s - 4ms/step - loss: 0.0046
# Epoch 59/100
# 34/34 - 0s - 4ms/step - loss: 0.0047
# Epoch 60/100
# 34/34 - 0s - 4ms/step - loss: 0.0040
# Epoch 61/100
# 34/34 - 0s - 4ms/step - loss: 0.0046
# Epoch 62/100
# 34/34 - 0s - 4ms/step - loss: 0.0044
# Epoch 63/100
# 34/34 - 0s - 4ms/step - loss: 0.0040
# Epoch 64/100
# 34/34 - 0s - 9ms/step - loss: 0.0040
# Epoch 65/100
# 34/34 - 0s - 4ms/step - loss: 0.0040
# Epoch 66/100
# 34/34 - 0s - 9ms/step - loss: 0.0038
# Epoch 67/100
# 34/34 - 0s - 4ms/step - loss: 0.0042
# Epoch 68/100
# 34/34 - 0s - 4ms/step - loss: 0.0038
# Epoch 69/100
# 34/34 - 0s - 4ms/step - loss: 0.0042
# Epoch 70/100
# 34/34 - 0s - 4ms/step - loss: 0.0040
# Epoch 71/100
# 34/34 - 0s - 4ms/step - loss: 0.0038
# Epoch 72/100
# 34/34 - 0s - 4ms/step - loss: 0.0037
# Epoch 73/100
# 34/34 - 0s - 4ms/step - loss: 0.0033
# Epoch 74/100
# 34/34 - 0s - 4ms/step - loss: 0.0037
# Epoch 75/100
# 34/34 - 0s - 4ms/step - loss: 0.0035
# Epoch 76/100
# 34/34 - 0s - 4ms/step - loss: 0.0030
# Epoch 77/100
# 34/34 - 0s - 4ms/step - loss: 0.0036
# Epoch 78/100
# 34/34 - 0s - 4ms/step - loss: 0.0034
# Epoch 79/100
# 34/34 - 0s - 4ms/step - loss: 0.0036
# Epoch 80/100
# 34/34 - 0s - 4ms/step - loss: 0.0032
# Epoch 81/100
# 34/34 - 0s - 6ms/step - loss: 0.0032
# Epoch 82/100
# 34/34 - 0s - 8ms/step - loss: 0.0034
# Epoch 83/100
# 34/34 - 0s - 9ms/step - loss: 0.0032
# Epoch 84/100
# 34/34 - 0s - 9ms/step - loss: 0.0032
# Epoch 85/100
# 34/34 - 0s - 9ms/step - loss: 0.0031
# Epoch 86/100
# 34/34 - 0s - 9ms/step - loss: 0.0028
# Epoch 87/100
# 34/34 - 0s - 9ms/step - loss: 0.0028
# Epoch 88/100
# 34/34 - 0s - 8ms/step - loss: 0.0029
# Epoch 89/100
# 34/34 - 0s - 8ms/step - loss: 0.0030
# Epoch 90/100
# 34/34 - 0s - 4ms/step - loss: 0.0029
# Epoch 91/100
# 34/34 - 0s - 4ms/step - loss: 0.0029
# Epoch 92/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 93/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 94/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 95/100
# 34/34 - 0s - 9ms/step - loss: 0.0024
# Epoch 96/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 97/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 98/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 99/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 100/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Processing FEDERALBNK.NS...
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 - 2s - 60ms/step - loss: 0.1445
# Epoch 2/100
# 34/34 - 0s - 4ms/step - loss: 0.0977
# Epoch 3/100
# 34/34 - 0s - 4ms/step - loss: 0.0620
# Epoch 4/100
# 34/34 - 0s - 4ms/step - loss: 0.0369
# Epoch 5/100
# 34/34 - 0s - 4ms/step - loss: 0.0240
# Epoch 6/100
# 34/34 - 0s - 4ms/step - loss: 0.0194
# Epoch 7/100
# 34/34 - 0s - 4ms/step - loss: 0.0170
# Epoch 8/100
# 34/34 - 0s - 4ms/step - loss: 0.0159
# Epoch 9/100
# 34/34 - 0s - 4ms/step - loss: 0.0148
# Epoch 10/100
# 34/34 - 0s - 4ms/step - loss: 0.0143
# Epoch 11/100
# 34/34 - 0s - 4ms/step - loss: 0.0130
# Epoch 12/100
# 34/34 - 0s - 4ms/step - loss: 0.0114
# Epoch 13/100
# 34/34 - 0s - 4ms/step - loss: 0.0107
# Epoch 14/100
# 34/34 - 0s - 4ms/step - loss: 0.0089
# Epoch 15/100
# 34/34 - 0s - 4ms/step - loss: 0.0087
# Epoch 16/100
# 34/34 - 0s - 5ms/step - loss: 0.0073
# Epoch 17/100
# 34/34 - 0s - 8ms/step - loss: 0.0066
# Epoch 18/100
# 34/34 - 0s - 4ms/step - loss: 0.0064
# Epoch 19/100
# 34/34 - 0s - 4ms/step - loss: 0.0063
# Epoch 20/100
# 34/34 - 0s - 4ms/step - loss: 0.0058
# Epoch 21/100
# 34/34 - 0s - 4ms/step - loss: 0.0056
# Epoch 22/100
# 34/34 - 0s - 4ms/step - loss: 0.0050
# Epoch 23/100
# 34/34 - 0s - 4ms/step - loss: 0.0049
# Epoch 24/100
# 34/34 - 0s - 4ms/step - loss: 0.0047
# Epoch 25/100
# 34/34 - 0s - 4ms/step - loss: 0.0044
# Epoch 26/100
# 34/34 - 0s - 4ms/step - loss: 0.0043
# Epoch 27/100
# 34/34 - 0s - 4ms/step - loss: 0.0043
# Epoch 28/100
# 34/34 - 0s - 4ms/step - loss: 0.0036
# Epoch 29/100
# 34/34 - 0s - 4ms/step - loss: 0.0044
# Epoch 30/100
# 34/34 - 0s - 4ms/step - loss: 0.0046
# Epoch 31/100
# 34/34 - 0s - 4ms/step - loss: 0.0035
# Epoch 32/100
# 34/34 - 0s - 4ms/step - loss: 0.0036
# Epoch 33/100
# 34/34 - 0s - 4ms/step - loss: 0.0038
# Epoch 34/100
# 34/34 - 0s - 4ms/step - loss: 0.0038
# Epoch 35/100
# 34/34 - 0s - 4ms/step - loss: 0.0035
# Epoch 36/100
# 34/34 - 0s - 5ms/step - loss: 0.0034
# Epoch 37/100
# 34/34 - 0s - 9ms/step - loss: 0.0036
# Epoch 38/100
# 34/34 - 0s - 9ms/step - loss: 0.0034
# Epoch 39/100
# 34/34 - 0s - 6ms/step - loss: 0.0033
# Epoch 40/100
# 34/34 - 0s - 9ms/step - loss: 0.0032
# Epoch 41/100
# 34/34 - 0s - 9ms/step - loss: 0.0031
# Epoch 42/100
# 34/34 - 0s - 9ms/step - loss: 0.0032
# Epoch 43/100
# 34/34 - 0s - 6ms/step - loss: 0.0030
# Epoch 44/100
# 34/34 - 0s - 8ms/step - loss: 0.0027
# Epoch 45/100
# 34/34 - 0s - 8ms/step - loss: 0.0028
# Epoch 46/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 47/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 48/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 49/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 50/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 51/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 52/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 53/100
# 34/34 - 0s - 4ms/step - loss: 0.0026
# Epoch 54/100
# 34/34 - 0s - 4ms/step - loss: 0.0022
# Epoch 55/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 56/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 57/100
# 34/34 - 0s - 4ms/step - loss: 0.0022
# Epoch 58/100
# 34/34 - 0s - 4ms/step - loss: 0.0026
# Epoch 59/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 60/100
# 34/34 - 0s - 5ms/step - loss: 0.0023
# Epoch 61/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 62/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 63/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 64/100
# 34/34 - 0s - 4ms/step - loss: 0.0022
# Epoch 65/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 66/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 67/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 68/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 69/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 70/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 71/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 72/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 73/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 74/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 75/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 76/100
# 34/34 - 0s - 4ms/step - loss: 0.0017
# Epoch 77/100
# 34/34 - 0s - 4ms/step - loss: 0.0017
# Epoch 78/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 79/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 80/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 81/100
# 34/34 - 0s - 4ms/step - loss: 0.0017
# Epoch 82/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 83/100
# 34/34 - 0s - 5ms/step - loss: 0.0016
# Epoch 84/100
# 34/34 - 0s - 8ms/step - loss: 0.0017
# Epoch 85/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 86/100
# 34/34 - 0s - 4ms/step - loss: 0.0017
# Epoch 87/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 88/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 89/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 90/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 91/100
# 34/34 - 0s - 4ms/step - loss: 0.0015
# Epoch 92/100
# 34/34 - 0s - 4ms/step - loss: 0.0015
# Epoch 93/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 94/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 95/100
# 34/34 - 0s - 4ms/step - loss: 0.0014
# Epoch 96/100
# 34/34 - 0s - 4ms/step - loss: 0.0015
# Epoch 97/100
# 34/34 - 0s - 5ms/step - loss: 0.0016
# Epoch 98/100
# 34/34 - 0s - 4ms/step - loss: 0.0015
# Epoch 99/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 100/100
# 34/34 - 0s - 4ms/step - loss: 0.0015
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# [*********************100%***********************]  1 of 1 completed
# Processing IDFCFIRSTB.NS...
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 - 3s - 75ms/step - loss: 0.2009
# Epoch 2/100
# 34/34 - 0s - 9ms/step - loss: 0.1427
# Epoch 3/100
# 34/34 - 0s - 8ms/step - loss: 0.0946
# Epoch 4/100
# 34/34 - 0s - 9ms/step - loss: 0.0571
# Epoch 5/100
# 34/34 - 0s - 5ms/step - loss: 0.0359
# Epoch 6/100
# 34/34 - 0s - 9ms/step - loss: 0.0286
# Epoch 7/100
# 34/34 - 0s - 8ms/step - loss: 0.0231
# Epoch 8/100
# 34/34 - 0s - 4ms/step - loss: 0.0201
# Epoch 9/100
# 34/34 - 0s - 4ms/step - loss: 0.0191
# Epoch 10/100
# 34/34 - 0s - 4ms/step - loss: 0.0171
# Epoch 11/100
# 34/34 - 0s - 4ms/step - loss: 0.0145
# Epoch 12/100
# 34/34 - 0s - 4ms/step - loss: 0.0146
# Epoch 13/100
# 34/34 - 0s - 4ms/step - loss: 0.0120
# Epoch 14/100
# 34/34 - 0s - 4ms/step - loss: 0.0108
# Epoch 15/100
# 34/34 - 0s - 4ms/step - loss: 0.0102
# Epoch 16/100
# 34/34 - 0s - 4ms/step - loss: 0.0092
# Epoch 17/100
# 34/34 - 0s - 4ms/step - loss: 0.0085
# Epoch 18/100
# 34/34 - 0s - 4ms/step - loss: 0.0081
# Epoch 19/100
# 34/34 - 0s - 4ms/step - loss: 0.0075
# Epoch 20/100
# 34/34 - 0s - 5ms/step - loss: 0.0067
# Epoch 21/100
# 34/34 - 0s - 4ms/step - loss: 0.0070
# Epoch 22/100
# 34/34 - 0s - 4ms/step - loss: 0.0061
# Epoch 23/100
# 34/34 - 0s - 4ms/step - loss: 0.0075
# Epoch 24/100
# 34/34 - 0s - 4ms/step - loss: 0.0060
# Epoch 25/100
# 34/34 - 0s - 4ms/step - loss: 0.0057
# Epoch 26/100
# 34/34 - 0s - 4ms/step - loss: 0.0062
# Epoch 27/100
# 34/34 - 0s - 4ms/step - loss: 0.0064
# Epoch 28/100
# 34/34 - 0s - 4ms/step - loss: 0.0058
# Epoch 29/100
# 34/34 - 0s - 4ms/step - loss: 0.0062
# Epoch 30/100
# 34/34 - 0s - 4ms/step - loss: 0.0055
# Epoch 31/100
# 34/34 - 0s - 4ms/step - loss: 0.0058
# Epoch 32/100
# 34/34 - 0s - 4ms/step - loss: 0.0057
# Epoch 33/100
# 34/34 - 0s - 4ms/step - loss: 0.0055
# Epoch 34/100
# 34/34 - 0s - 4ms/step - loss: 0.0055
# Epoch 35/100
# 34/34 - 0s - 4ms/step - loss: 0.0051
# Epoch 36/100
# 34/34 - 0s - 4ms/step - loss: 0.0049
# Epoch 37/100
# 34/34 - 0s - 4ms/step - loss: 0.0053
# Epoch 38/100
# 34/34 - 0s - 4ms/step - loss: 0.0051
# Epoch 39/100
# 34/34 - 0s - 4ms/step - loss: 0.0052
# Epoch 40/100
# 34/34 - 0s - 4ms/step - loss: 0.0050
# Epoch 41/100
# 34/34 - 0s - 4ms/step - loss: 0.0050
# Epoch 42/100
# 34/34 - 0s - 4ms/step - loss: 0.0044
# Epoch 43/100
# 34/34 - 0s - 4ms/step - loss: 0.0050
# Epoch 44/100
# 34/34 - 0s - 4ms/step - loss: 0.0047
# Epoch 45/100
# 34/34 - 0s - 4ms/step - loss: 0.0042
# Epoch 46/100
# 34/34 - 0s - 4ms/step - loss: 0.0041
# Epoch 47/100
# 34/34 - 0s - 4ms/step - loss: 0.0046
# Epoch 48/100
# 34/34 - 0s - 4ms/step - loss: 0.0047
# Epoch 49/100
# 34/34 - 0s - 4ms/step - loss: 0.0039
# Epoch 50/100
# 34/34 - 0s - 4ms/step - loss: 0.0042
# Epoch 51/100
# 34/34 - 0s - 4ms/step - loss: 0.0042
# Epoch 52/100
# 34/34 - 0s - 4ms/step - loss: 0.0042
# Epoch 53/100
# 34/34 - 0s - 4ms/step - loss: 0.0038
# Epoch 54/100
# 34/34 - 0s - 4ms/step - loss: 0.0040
# Epoch 55/100
# 34/34 - 0s - 4ms/step - loss: 0.0036
# Epoch 56/100
# 34/34 - 0s - 4ms/step - loss: 0.0040
# Epoch 57/100
# 34/34 - 0s - 4ms/step - loss: 0.0040
# Epoch 58/100
# 34/34 - 0s - 4ms/step - loss: 0.0035
# Epoch 59/100
# 34/34 - 0s - 8ms/step - loss: 0.0036
# Epoch 60/100
# 34/34 - 0s - 4ms/step - loss: 0.0035
# Epoch 61/100
# 34/34 - 0s - 4ms/step - loss: 0.0036
# Epoch 62/100
# 34/34 - 0s - 4ms/step - loss: 0.0036
# Epoch 63/100
# 34/34 - 0s - 4ms/step - loss: 0.0032
# Epoch 64/100
# 34/34 - 0s - 5ms/step - loss: 0.0034
# Epoch 65/100
# 34/34 - 0s - 4ms/step - loss: 0.0035
# Epoch 66/100
# 34/34 - 0s - 4ms/step - loss: 0.0036
# Epoch 67/100
# 34/34 - 0s - 4ms/step - loss: 0.0029
# Epoch 68/100
# 34/34 - 0s - 4ms/step - loss: 0.0037
# Epoch 69/100
# 34/34 - 0s - 4ms/step - loss: 0.0033
# Epoch 70/100
# 34/34 - 0s - 4ms/step - loss: 0.0030
# Epoch 71/100
# 34/34 - 0s - 5ms/step - loss: 0.0028
# Epoch 72/100
# 34/34 - 0s - 4ms/step - loss: 0.0029
# Epoch 73/100
# 34/34 - 0s - 4ms/step - loss: 0.0030
# Epoch 74/100
# 34/34 - 0s - 10ms/step - loss: 0.0024
# Epoch 75/100
# 34/34 - 0s - 9ms/step - loss: 0.0031
# Epoch 76/100
# 34/34 - 0s - 9ms/step - loss: 0.0030
# Epoch 77/100
# 34/34 - 0s - 6ms/step - loss: 0.0028
# Epoch 78/100
# 34/34 - 0s - 6ms/step - loss: 0.0029
# Epoch 79/100
# 34/34 - 0s - 9ms/step - loss: 0.0032
# Epoch 80/100
# 34/34 - 0s - 9ms/step - loss: 0.0027
# Epoch 81/100
# 34/34 - 0s - 8ms/step - loss: 0.0030
# Epoch 82/100
# 34/34 - 0s - 8ms/step - loss: 0.0032
# Epoch 83/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 84/100
# 34/34 - 0s - 5ms/step - loss: 0.0025
# Epoch 85/100
# 34/34 - 0s - 8ms/step - loss: 0.0027
# Epoch 86/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 87/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 88/100
# 34/34 - 0s - 4ms/step - loss: 0.0026
# Epoch 89/100
# 34/34 - 0s - 4ms/step - loss: 0.0026
# Epoch 90/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 91/100
# 34/34 - 0s - 9ms/step - loss: 0.0023
# Epoch 92/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 93/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 94/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 95/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 96/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 97/100
# 34/34 - 0s - 5ms/step - loss: 0.0026
# Epoch 98/100
# 34/34 - 0s - 8ms/step - loss: 0.0024
# Epoch 99/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 100/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Processing PNB.NS...
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 - 3s - 76ms/step - loss: 0.0752
# Epoch 2/100
# 34/34 - 0s - 4ms/step - loss: 0.0537
# Epoch 3/100
# 34/34 - 0s - 5ms/step - loss: 0.0400
# Epoch 4/100
# 34/34 - 0s - 4ms/step - loss: 0.0322
# Epoch 5/100
# 34/34 - 0s - 4ms/step - loss: 0.0272
# Epoch 6/100
# 34/34 - 0s - 4ms/step - loss: 0.0220
# Epoch 7/100
# 34/34 - 0s - 4ms/step - loss: 0.0196
# Epoch 8/100
# 34/34 - 0s - 4ms/step - loss: 0.0140
# Epoch 9/100
# 34/34 - 0s - 4ms/step - loss: 0.0112
# Epoch 10/100
# 34/34 - 0s - 4ms/step - loss: 0.0086
# Epoch 11/100
# 34/34 - 0s - 4ms/step - loss: 0.0064
# Epoch 12/100
# 34/34 - 0s - 4ms/step - loss: 0.0056
# Epoch 13/100
# 34/34 - 0s - 4ms/step - loss: 0.0041
# Epoch 14/100
# 34/34 - 0s - 4ms/step - loss: 0.0034
# Epoch 15/100
# 34/34 - 0s - 5ms/step - loss: 0.0033
# Epoch 16/100
# 34/34 - 0s - 8ms/step - loss: 0.0039
# Epoch 17/100
# 34/34 - 0s - 4ms/step - loss: 0.0033
# Epoch 18/100
# 34/34 - 0s - 4ms/step - loss: 0.0037
# Epoch 19/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 20/100
# 34/34 - 0s - 4ms/step - loss: 0.0035
# Epoch 21/100
# 34/34 - 0s - 5ms/step - loss: 0.0032
# Epoch 22/100
# 34/34 - 0s - 4ms/step - loss: 0.0040
# Epoch 23/100
# 34/34 - 0s - 10ms/step - loss: 0.0032
# Epoch 24/100
# 34/34 - 0s - 9ms/step - loss: 0.0030
# Epoch 25/100
# 34/34 - 0s - 9ms/step - loss: 0.0028
# Epoch 26/100
# 34/34 - 0s - 6ms/step - loss: 0.0026
# Epoch 27/100
# 34/34 - 0s - 9ms/step - loss: 0.0035
# Epoch 28/100
# 34/34 - 0s - 9ms/step - loss: 0.0027
# Epoch 29/100
# 34/34 - 0s - 9ms/step - loss: 0.0030
# Epoch 30/100
# 34/34 - 0s - 7ms/step - loss: 0.0029
# Epoch 31/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 32/100
# 34/34 - 0s - 9ms/step - loss: 0.0026
# Epoch 33/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 34/100
# 34/34 - 0s - 9ms/step - loss: 0.0019
# Epoch 35/100
# 34/34 - 0s - 4ms/step - loss: 0.0032
# Epoch 36/100
# 34/34 - 0s - 4ms/step - loss: 0.0026
# Epoch 37/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 38/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 39/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 40/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 41/100
# 34/34 - 0s - 8ms/step - loss: 0.0022
# Epoch 42/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 43/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 44/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 45/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 46/100
# 34/34 - 0s - 4ms/step - loss: 0.0021
# Epoch 47/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 48/100
# 34/34 - 0s - 4ms/step - loss: 0.0022
# Epoch 49/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 50/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 51/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 52/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 53/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 54/100
# 34/34 - 0s - 9ms/step - loss: 0.0022
# Epoch 55/100
# 34/34 - 0s - 4ms/step - loss: 0.0019
# Epoch 56/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 57/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 58/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 59/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 60/100
# 34/34 - 0s - 5ms/step - loss: 0.0018
# Epoch 61/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 62/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 63/100
# 34/34 - 0s - 9ms/step - loss: 0.0020
# Epoch 64/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 65/100
# 34/34 - 0s - 4ms/step - loss: 0.0015
# Epoch 66/100
# 34/34 - 0s - 5ms/step - loss: 0.0019
# Epoch 67/100
# 34/34 - 0s - 9ms/step - loss: 0.0023
# Epoch 68/100
# 34/34 - 0s - 8ms/step - loss: 0.0017
# Epoch 69/100
# 34/34 - 0s - 4ms/step - loss: 0.0019
# Epoch 70/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 71/100
# 34/34 - 0s - 5ms/step - loss: 0.0018
# Epoch 72/100
# 34/34 - 0s - 9ms/step - loss: 0.0019
# Epoch 73/100
# 34/34 - 0s - 9ms/step - loss: 0.0019
# Epoch 74/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 75/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 76/100
# 34/34 - 0s - 5ms/step - loss: 0.0023
# Epoch 77/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 78/100
# 34/34 - 0s - 4ms/step - loss: 0.0017
# Epoch 79/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 80/100
# 34/34 - 0s - 4ms/step - loss: 0.0017
# Epoch 81/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 82/100
# 34/34 - 0s - 4ms/step - loss: 0.0015
# Epoch 83/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 84/100
# 34/34 - 0s - 9ms/step - loss: 0.0015
# Epoch 85/100
# 34/34 - 0s - 4ms/step - loss: 0.0018
# Epoch 86/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# Epoch 87/100
# 34/34 - 0s - 4ms/step - loss: 0.0014
# Epoch 88/100
# 34/34 - 0s - 4ms/step - loss: 0.0017
# Epoch 89/100
# 34/34 - 0s - 5ms/step - loss: 0.0016
# Epoch 90/100
# 34/34 - 0s - 10ms/step - loss: 0.0015
# Epoch 91/100
# 34/34 - 0s - 8ms/step - loss: 0.0022
# Epoch 92/100
# 34/34 - 0s - 9ms/step - loss: 0.0017
# Epoch 93/100
# 34/34 - 0s - 7ms/step - loss: 0.0014
# Epoch 94/100
# 34/34 - 0s - 7ms/step - loss: 0.0016
# Epoch 95/100
# 34/34 - 0s - 9ms/step - loss: 0.0014
# Epoch 96/100
# 34/34 - 0s - 9ms/step - loss: 0.0016
# Epoch 97/100
# 34/34 - 0s - 9ms/step - loss: 0.0017
# Epoch 98/100
# 34/34 - 0s - 5ms/step - loss: 0.0016
# Epoch 99/100
# 34/34 - 0s - 4ms/step - loss: 0.0016
# Epoch 100/100
# 34/34 - 0s - 9ms/step - loss: 0.0016
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Processing BANKBARODA.NS...
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 34/34 - 2s - 63ms/step - loss: 0.1447
# Epoch 2/100
# 34/34 - 0s - 4ms/step - loss: 0.1051
# Epoch 3/100
# 34/34 - 0s - 4ms/step - loss: 0.0770
# Epoch 4/100
# 34/34 - 0s - 4ms/step - loss: 0.0556
# Epoch 5/100
# 34/34 - 0s - 4ms/step - loss: 0.0420
# Epoch 6/100
# 34/34 - 0s - 4ms/step - loss: 0.0338
# Epoch 7/100
# 34/34 - 0s - 4ms/step - loss: 0.0297
# Epoch 8/100
# 34/34 - 0s - 4ms/step - loss: 0.0247
# Epoch 9/100
# 34/34 - 0s - 4ms/step - loss: 0.0237
# Epoch 10/100
# 34/34 - 0s - 4ms/step - loss: 0.0190
# Epoch 11/100
# 34/34 - 0s - 9ms/step - loss: 0.0162
# Epoch 12/100
# 34/34 - 0s - 4ms/step - loss: 0.0143
# Epoch 13/100
# 34/34 - 0s - 5ms/step - loss: 0.0124
# Epoch 14/100
# 34/34 - 0s - 4ms/step - loss: 0.0107
# Epoch 15/100
# 34/34 - 0s - 4ms/step - loss: 0.0092
# Epoch 16/100
# 34/34 - 0s - 4ms/step - loss: 0.0079
# Epoch 17/100
# 34/34 - 0s - 4ms/step - loss: 0.0067
# Epoch 18/100
# 34/34 - 0s - 4ms/step - loss: 0.0073
# Epoch 19/100
# 34/34 - 0s - 4ms/step - loss: 0.0069
# Epoch 20/100
# 34/34 - 0s - 4ms/step - loss: 0.0070
# Epoch 21/100
# 34/34 - 0s - 4ms/step - loss: 0.0063
# Epoch 22/100
# 34/34 - 0s - 4ms/step - loss: 0.0053
# Epoch 23/100
# 34/34 - 0s - 4ms/step - loss: 0.0070
# Epoch 24/100
# 34/34 - 0s - 5ms/step - loss: 0.0052
# Epoch 25/100
# 34/34 - 0s - 4ms/step - loss: 0.0053
# Epoch 26/100
# 34/34 - 0s - 4ms/step - loss: 0.0052
# Epoch 27/100
# 34/34 - 0s - 4ms/step - loss: 0.0060
# Epoch 28/100
# 34/34 - 0s - 4ms/step - loss: 0.0051
# Epoch 29/100
# 34/34 - 0s - 4ms/step - loss: 0.0047
# Epoch 30/100
# 34/34 - 0s - 4ms/step - loss: 0.0052
# Epoch 31/100
# 34/34 - 0s - 5ms/step - loss: 0.0052
# Epoch 32/100
# 34/34 - 0s - 4ms/step - loss: 0.0052
# Epoch 33/100
# 34/34 - 0s - 4ms/step - loss: 0.0055
# Epoch 34/100
# 34/34 - 0s - 4ms/step - loss: 0.0045
# Epoch 35/100
# 34/34 - 0s - 4ms/step - loss: 0.0053
# Epoch 36/100
# 34/34 - 0s - 4ms/step - loss: 0.0050
# Epoch 37/100
# 34/34 - 0s - 4ms/step - loss: 0.0043
# Epoch 38/100
# 34/34 - 0s - 5ms/step - loss: 0.0045
# Epoch 39/100
# 34/34 - 0s - 8ms/step - loss: 0.0045
# Epoch 40/100
# 34/34 - 0s - 4ms/step - loss: 0.0043
# Epoch 41/100
# 34/34 - 0s - 4ms/step - loss: 0.0041
# Epoch 42/100
# 34/34 - 0s - 4ms/step - loss: 0.0036
# Epoch 43/100
# 34/34 - 0s - 11ms/step - loss: 0.0039
# Epoch 44/100
# 34/34 - 0s - 8ms/step - loss: 0.0038
# Epoch 45/100
# 34/34 - 0s - 6ms/step - loss: 0.0037
# Epoch 46/100
# 34/34 - 0s - 8ms/step - loss: 0.0034
# Epoch 47/100
# 34/34 - 0s - 6ms/step - loss: 0.0034
# Epoch 48/100
# 34/34 - 0s - 9ms/step - loss: 0.0042
# Epoch 49/100
# 34/34 - 0s - 9ms/step - loss: 0.0035
# Epoch 50/100
# 34/34 - 0s - 9ms/step - loss: 0.0039
# Epoch 51/100
# 34/34 - 0s - 7ms/step - loss: 0.0037
# Epoch 52/100
# 34/34 - 0s - 9ms/step - loss: 0.0033
# Epoch 53/100
# 34/34 - 0s - 4ms/step - loss: 0.0035
# Epoch 54/100
# 34/34 - 0s - 4ms/step - loss: 0.0034
# Epoch 55/100
# 34/34 - 0s - 4ms/step - loss: 0.0035
# Epoch 56/100
# 34/34 - 0s - 4ms/step - loss: 0.0037
# Epoch 57/100
# 34/34 - 0s - 5ms/step - loss: 0.0028
# Epoch 58/100
# 34/34 - 0s - 8ms/step - loss: 0.0030
# Epoch 59/100
# 34/34 - 0s - 4ms/step - loss: 0.0030
# Epoch 60/100
# 34/34 - 0s - 9ms/step - loss: 0.0031
# Epoch 61/100
# 34/34 - 0s - 4ms/step - loss: 0.0031
# Epoch 62/100
# 34/34 - 0s - 4ms/step - loss: 0.0036
# Epoch 63/100
# 34/34 - 0s - 8ms/step - loss: 0.0030
# Epoch 64/100
# 34/34 - 0s - 4ms/step - loss: 0.0031
# Epoch 65/100
# 34/34 - 0s - 4ms/step - loss: 0.0030
# Epoch 66/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 67/100
# 34/34 - 0s - 4ms/step - loss: 0.0030
# Epoch 68/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 69/100
# 34/34 - 0s - 9ms/step - loss: 0.0028
# Epoch 70/100
# 34/34 - 0s - 4ms/step - loss: 0.0035
# Epoch 71/100
# 34/34 - 0s - 4ms/step - loss: 0.0026
# Epoch 72/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 73/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 74/100
# 34/34 - 0s - 5ms/step - loss: 0.0028
# Epoch 75/100
# 34/34 - 0s - 4ms/step - loss: 0.0032
# Epoch 76/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 77/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 78/100
# 34/34 - 0s - 4ms/step - loss: 0.0026
# Epoch 79/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 80/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 81/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 82/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 83/100
# 34/34 - 0s - 8ms/step - loss: 0.0027
# Epoch 84/100
# 34/34 - 0s - 4ms/step - loss: 0.0028
# Epoch 85/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 86/100
# 34/34 - 0s - 4ms/step - loss: 0.0026
# Epoch 87/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 88/100
# 34/34 - 0s - 5ms/step - loss: 0.0026
# Epoch 89/100
# 34/34 - 0s - 8ms/step - loss: 0.0025
# Epoch 90/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 91/100
# 34/34 - 0s - 4ms/step - loss: 0.0027
# Epoch 92/100
# 34/34 - 0s - 9ms/step - loss: 0.0025
# Epoch 93/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 94/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 95/100
# 34/34 - 0s - 4ms/step - loss: 0.0022
# Epoch 96/100
# 34/34 - 0s - 4ms/step - loss: 0.0023
# Epoch 97/100
# 34/34 - 0s - 4ms/step - loss: 0.0024
# Epoch 98/100
# 34/34 - 0s - 4ms/step - loss: 0.0022
# Epoch 99/100
# 34/34 - 0s - 4ms/step - loss: 0.0025
# Epoch 100/100
# 34/34 - 0s - 4ms/step - loss: 0.0020
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#           Symbol  Predicted Close Price  Accuracy (%)       MSE  R-squared
# 0   ICICIBANK.NS            1439.811768     96.058139  0.000207   0.960581
# 1    AXISBANK.NS            1192.959229     95.629114  0.000284   0.956291
# 2        SBIN.NS             786.414734     91.396848  0.000254   0.913968
# 3  INDUSINDBK.NS             776.437561     99.210145  0.000306   0.992101
# 4  FEDERALBNK.NS             199.026260     94.469382  0.000335   0.944694
# 5  IDFCFIRSTB.NS              66.058601     96.609367  0.000302   0.966094
# 6         PNB.NS             101.369118     97.093232  0.000314   0.970932
# 7  BANKBARODA.NS             233.713104     84.731256  0.000824   0.847313

# %% [markdown]
# GRU With dates in x axis

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
import matplotlib.pyplot as plt

# Function to retrieve data for a given symbol with only open and close prices
def get_stock_data(symbol, start_date, end_date):
    try:
        data = yf.download(symbol, start=start_date, end=end_date)[['Open', 'Close']]
        return data
    except Exception as e:
        print(f"Failed to download data for {symbol}: {e}")
        return None

# Function to preprocess data and split into training and testing sets
def preprocess_data(data, train_percentage=0.8):
    if data is None or data.empty:
        return None, None, None

    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data)

    train_size = int(len(scaled_data) * train_percentage)
    if train_size == 0:
        return None, None, None

    train_data = scaled_data[:train_size]
    test_data = scaled_data[train_size:]

    return train_data, test_data, scaler

# Function to create GRU model with refined architecture
def create_gru_model(input_shape):
    model = Sequential()
    model.add(GRU(units=128, input_shape=input_shape))
    model.add(Dropout(0.2))
    model.add(Dense(units=2))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# Function to train GRU model with adjusted epochs and batch size for higher accuracy
def train_model(model, X_train, y_train):
    model.fit(X_train, y_train, epochs=25, batch_size=16, verbose=2)

# Function to evaluate model performance
def evaluate_model(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    accuracy = r2_score(y_true, y_pred)
    return mse, accuracy

# Function to plot predicted vs actual prices for a stock
def plot_predictions(symbol, actual_prices, predicted_prices, dates, scaler):
    actual_prices = scaler.inverse_transform(actual_prices)
    predicted_prices = scaler.inverse_transform(predicted_prices)

    plt.figure(figsize=(16, 8))
    plt.plot(dates, actual_prices[:, 1], label='Actual Close Prices')
    plt.plot(dates, predicted_prices[:, 1], label='Predicted Close Prices')
    plt.title(f"Actual vs Predicted Close Prices for {symbol}")
    plt.xlabel("Date")
    plt.ylabel("Close Price (INR)")
    plt.xticks(rotation=45)
    plt.legend()
    plt.show()

# Main function with further refined settings for improved accuracy
def main():
    symbols =  ['ICICIBANK.NS', 'AXISBANK.NS', 'SBIN.NS', 'INDUSINDBK.NS', 'FEDERALBNK.NS', 'IDFCFIRSTB.NS', 'PNB.NS', 'BANKBARODA.NS']
    end_date = input("Enter end date (YYYY-MM-DD): ")
    end_date_dt = pd.to_datetime(end_date)
    start_date_dt = pd.to_datetime('2000-01-01')

    results = []

    for symbol in symbols:
        print(f"Processing {symbol}...")
        data = get_stock_data(symbol, start_date=start_date_dt, end_date=end_date)
        if data is None:
            print(f"No data available for {symbol}. Skipping...")
            continue

        train_data, test_data, scaler = preprocess_data(data)
        if train_data is None or test_data is None or scaler is None:
            print(f"Insufficient data for {symbol}. Skipping...")
            continue

        X_train, y_train = train_data[:-1], train_data[1:]
        X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))  # Reshape for GRU input
        X_test, y_test = test_data[:-1], test_data[1:]
        X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))  # Reshape for GRU input

        model = create_gru_model(input_shape=(1, 2))
        train_model(model, X_train, y_train)

        predictions = model.predict(X_test)

        mse, accuracy = evaluate_model(y_test, predictions)

        dates = data.index[-len(predictions):]  # Dates for the test data

        plot_predictions(symbol, test_data[1:], predictions, dates, scaler)

        results.append({
            'Symbol': symbol,
            'Predicted Close Price': scaler.inverse_transform(predictions)[-1][1],
            'Accuracy (%)': accuracy * 100,
            'MSE': mse,
            'R-squared': accuracy
        })
    if results:
        results_df = pd.DataFrame(results)
        print(results_df)

if __name__ == "__main__":
    main()
# Out:
# Enter end date (YYYY-MM-DD): 2025-01-07
# Processing ICICIBANK.NS...
# [*********************100%***********************]  1 of 1 completed
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/25
# 280/280 - 3s - 9ms/step - loss: 0.0015
# Epoch 2/25
# 280/280 - 1s - 5ms/step - loss: 1.0952e-04
# Epoch 3/25
# 280/280 - 1s - 3ms/step - loss: 9.0206e-05
# Epoch 4/25
# 280/280 - 1s - 3ms/step - loss: 7.5452e-05
# Epoch 5/25
# 280/280 - 1s - 3ms/step - loss: 6.7202e-05
# Epoch 6/25
# 280/280 - 1s - 3ms/step - loss: 6.4645e-05
# Epoch 7/25
# 280/280 - 1s - 2ms/step - loss: 5.7652e-05
# Epoch 8/25
# 280/280 - 1s - 2ms/step - loss: 5.5720e-05
# Epoch 9/25
# 280/280 - 1s - 2ms/step - loss: 5.0067e-05
# Epoch 10/25
# 280/280 - 1s - 2ms/step - loss: 4.3261e-05
# Epoch 11/25
# 280/280 - 1s - 2ms/step - loss: 4.3751e-05
# Epoch 12/25
# 280/280 - 1s - 2ms/step - loss: 3.6327e-05
# Epoch 13/25
# 280/280 - 1s - 2ms/step - loss: 3.7276e-05
# Epoch 14/25
# 280/280 - 1s - 2ms/step - loss: 3.9317e-05
# Epoch 15/25
# 280/280 - 1s - 2ms/step - loss: 3.4405e-05
# Epoch 16/25
# 280/280 - 1s - 2ms/step - loss: 3.4137e-05
# Epoch 17/25
# 280/280 - 1s - 2ms/step - loss: 3.3597e-05
# Epoch 18/25
# 280/280 - 1s - 2ms/step - loss: 3.7249e-05
# Epoch 19/25
# 280/280 - 1s - 2ms/step - loss: 3.1254e-05
# Epoch 20/25
# 280/280 - 1s - 2ms/step - loss: 3.2613e-05
# Epoch 21/25
# 280/280 - 1s - 2ms/step - loss: 3.0214e-05
# Epoch 22/25
# 280/280 - 1s - 3ms/step - loss: 3.2295e-05
# Epoch 23/25
# 280/280 - 1s - 5ms/step - loss: 3.3693e-05
# Epoch 24/25
# 280/280 - 1s - 3ms/step - loss: 2.9965e-05
# Epoch 25/25
# 280/280 - 1s - 3ms/step - loss: 3.2992e-05
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Processing AXISBANK.NS...
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 312/312 - 2s - 8ms/step - loss: 0.0042
# Epoch 2/25
# 312/312 - 1s - 4ms/step - loss: 2.7121e-04
# Epoch 3/25
# 312/312 - 1s - 2ms/step - loss: 2.2973e-04
# Epoch 4/25
# 312/312 - 1s - 4ms/step - loss: 2.0001e-04
# Epoch 5/25
# 312/312 - 1s - 4ms/step - loss: 1.9514e-04
# Epoch 6/25
# 312/312 - 1s - 2ms/step - loss: 1.7851e-04
# Epoch 7/25
# 312/312 - 2s - 5ms/step - loss: 1.5044e-04
# Epoch 8/25
# 312/312 - 1s - 3ms/step - loss: 1.5265e-04
# Epoch 9/25
# 312/312 - 1s - 3ms/step - loss: 1.2806e-04
# Epoch 10/25
# 312/312 - 1s - 4ms/step - loss: 1.1765e-04
# Epoch 11/25
# 312/312 - 1s - 4ms/step - loss: 1.1613e-04
# Epoch 12/25
# 312/312 - 1s - 4ms/step - loss: 1.1085e-04
# Epoch 13/25
# 312/312 - 1s - 2ms/step - loss: 1.0045e-04
# Epoch 14/25
# 312/312 - 1s - 4ms/step - loss: 1.0096e-04
# Epoch 15/25
# 312/312 - 1s - 2ms/step - loss: 9.6481e-05
# Epoch 16/25
# 312/312 - 1s - 4ms/step - loss: 1.0036e-04
# Epoch 17/25
# 312/312 - 1s - 4ms/step - loss: 9.6477e-05
# Epoch 18/25
# 312/312 - 2s - 5ms/step - loss: 9.5688e-05
# Epoch 19/25
# 312/312 - 1s - 4ms/step - loss: 8.8738e-05
# Epoch 20/25
# 312/312 - 1s - 3ms/step - loss: 9.3030e-05
# Epoch 21/25
# 312/312 - 1s - 2ms/step - loss: 8.7043e-05
# Epoch 22/25
# 312/312 - 1s - 2ms/step - loss: 9.4233e-05
# Epoch 23/25
# 312/312 - 1s - 2ms/step - loss: 8.4303e-05
# Epoch 24/25
# 312/312 - 1s - 2ms/step - loss: 8.5198e-05
# Epoch 25/25
# 312/312 - 1s - 4ms/step - loss: 8.2013e-05
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# Processing SBIN.NS...
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 312/312 - 2s - 8ms/step - loss: 0.0026
# Epoch 2/25
# 312/312 - 1s - 2ms/step - loss: 1.7338e-04
# Epoch 3/25
# 312/312 - 2s - 5ms/step - loss: 1.5049e-04
# Epoch 4/25
# 312/312 - 1s - 4ms/step - loss: 1.2724e-04
# Epoch 5/25
# 312/312 - 1s - 3ms/step - loss: 1.1353e-04
# Epoch 6/25
# 312/312 - 1s - 3ms/step - loss: 1.1174e-04
# Epoch 7/25
# 312/312 - 1s - 4ms/step - loss: 9.5721e-05
# Epoch 8/25
# 312/312 - 1s - 2ms/step - loss: 8.7669e-05
# Epoch 9/25
# 312/312 - 1s - 4ms/step - loss: 7.8561e-05
# Epoch 10/25
# 312/312 - 1s - 4ms/step - loss: 7.4019e-05
# Epoch 11/25
# 312/312 - 1s - 2ms/step - loss: 7.0574e-05
# Epoch 12/25
# 312/312 - 1s - 2ms/step - loss: 6.6759e-05
# Epoch 13/25
# 312/312 - 1s - 2ms/step - loss: 6.4137e-05
# Epoch 14/25
# 312/312 - 1s - 2ms/step - loss: 5.9013e-05
# Epoch 15/25
# 312/312 - 1s - 2ms/step - loss: 5.5842e-05
# Epoch 16/25
# 312/312 - 2s - 5ms/step - loss: 5.4500e-05
# Epoch 17/25
# 312/312 - 1s - 4ms/step - loss: 5.3194e-05
# Epoch 18/25
# 312/312 - 1s - 3ms/step - loss: 5.1976e-05
# Epoch 19/25
# 312/312 - 1s - 2ms/step - loss: 5.0493e-05
# Epoch 20/25
# 312/312 - 1s - 2ms/step - loss: 5.2574e-05
# Epoch 21/25
# 312/312 - 1s - 4ms/step - loss: 4.8327e-05
# Epoch 22/25
# 312/312 - 1s - 2ms/step - loss: 4.8581e-05
# Epoch 23/25
# 312/312 - 1s - 2ms/step - loss: 4.8935e-05
# Epoch 24/25
# 312/312 - 1s - 4ms/step - loss: 5.0055e-05
# Epoch 25/25
# 312/312 - 1s - 4ms/step - loss: 5.2070e-05
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Processing INDUSINDBK.NS...
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 280/280 - 3s - 10ms/step - loss: 0.0088
# Epoch 2/25
# 280/280 - 1s - 3ms/step - loss: 7.4096e-04
# Epoch 3/25
# 280/280 - 1s - 5ms/step - loss: 6.6525e-04
# Epoch 4/25
# 280/280 - 1s - 2ms/step - loss: 5.8993e-04
# Epoch 5/25
# 280/280 - 1s - 2ms/step - loss: 5.1714e-04
# Epoch 6/25
# 280/280 - 1s - 2ms/step - loss: 5.6252e-04
# Epoch 7/25
# 280/280 - 1s - 2ms/step - loss: 4.4147e-04
# Epoch 8/25
# 280/280 - 1s - 2ms/step - loss: 4.0463e-04
# Epoch 9/25
# 280/280 - 1s - 2ms/step - loss: 4.2696e-04
# Epoch 10/25
# 280/280 - 1s - 2ms/step - loss: 3.8543e-04
# Epoch 11/25
# 280/280 - 1s - 2ms/step - loss: 3.6215e-04
# Epoch 12/25
# 280/280 - 1s - 2ms/step - loss: 3.4071e-04
# Epoch 13/25
# 280/280 - 1s - 2ms/step - loss: 3.2120e-04
# Epoch 14/25
# 280/280 - 1s - 2ms/step - loss: 3.2512e-04
# Epoch 15/25
# 280/280 - 1s - 2ms/step - loss: 2.6635e-04
# Epoch 16/25
# 280/280 - 1s - 2ms/step - loss: 3.2391e-04
# Epoch 17/25
# 280/280 - 1s - 2ms/step - loss: 2.7531e-04
# Epoch 18/25
# 280/280 - 1s - 2ms/step - loss: 2.9193e-04
# Epoch 19/25
# 280/280 - 1s - 2ms/step - loss: 2.5051e-04
# Epoch 20/25
# 280/280 - 1s - 3ms/step - loss: 2.7045e-04
# Epoch 21/25
# 280/280 - 1s - 5ms/step - loss: 2.6157e-04
# Epoch 22/25
# 280/280 - 1s - 4ms/step - loss: 2.6820e-04
# Epoch 23/25
# 280/280 - 1s - 2ms/step - loss: 2.6323e-04
# Epoch 24/25
# 280/280 - 1s - 2ms/step - loss: 2.6250e-04
# Epoch 25/25
# 280/280 - 1s - 2ms/step - loss: 2.5143e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Processing FEDERALBNK.NS...
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 312/312 - 2s - 8ms/step - loss: 0.0027
# Epoch 2/25
# 312/312 - 1s - 4ms/step - loss: 1.9186e-04
# Epoch 3/25
# 312/312 - 1s - 2ms/step - loss: 1.7944e-04
# Epoch 4/25
# 312/312 - 1s - 2ms/step - loss: 1.5688e-04
# Epoch 5/25
# 312/312 - 1s - 4ms/step - loss: 1.4539e-04
# Epoch 6/25
# 312/312 - 2s - 5ms/step - loss: 1.3832e-04
# Epoch 7/25
# 312/312 - 1s - 3ms/step - loss: 1.2619e-04
# Epoch 8/25
# 312/312 - 1s - 4ms/step - loss: 1.2034e-04
# Epoch 9/25
# 312/312 - 1s - 2ms/step - loss: 1.0485e-04
# Epoch 10/25
# 312/312 - 1s - 2ms/step - loss: 9.5444e-05
# Epoch 11/25
# 312/312 - 1s - 4ms/step - loss: 8.8823e-05
# Epoch 12/25
# 312/312 - 1s - 4ms/step - loss: 9.4296e-05
# Epoch 13/25
# 312/312 - 1s - 2ms/step - loss: 9.1177e-05
# Epoch 14/25
# 312/312 - 1s - 2ms/step - loss: 8.5662e-05
# Epoch 15/25
# 312/312 - 1s - 2ms/step - loss: 8.4529e-05
# Epoch 16/25
# 312/312 - 1s - 2ms/step - loss: 7.8279e-05
# Epoch 17/25
# 312/312 - 1s - 4ms/step - loss: 8.2774e-05
# Epoch 18/25
# 312/312 - 1s - 2ms/step - loss: 8.3199e-05
# Epoch 19/25
# 312/312 - 1s - 4ms/step - loss: 8.1981e-05
# Epoch 20/25
# 312/312 - 1s - 3ms/step - loss: 7.0490e-05
# Epoch 21/25
# 312/312 - 1s - 4ms/step - loss: 7.0454e-05
# Epoch 22/25
# 312/312 - 1s - 3ms/step - loss: 7.3723e-05
# Epoch 23/25
# 312/312 - 1s - 3ms/step - loss: 6.7729e-05
# Epoch 24/25
# 312/312 - 1s - 4ms/step - loss: 7.3975e-05
# Epoch 25/25
# 312/312 - 1s - 2ms/step - loss: 7.6366e-05
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [*********************100%***********************]  1 of 1 completed
# Processing IDFCFIRSTB.NS...
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 113/113 - 2s - 18ms/step - loss: 0.0192
# Epoch 2/25
# 113/113 - 0s - 3ms/step - loss: 0.0023
# Epoch 3/25
# 113/113 - 0s - 3ms/step - loss: 9.6451e-04
# Epoch 4/25
# 113/113 - 0s - 2ms/step - loss: 8.3938e-04
# Epoch 5/25
# 113/113 - 0s - 2ms/step - loss: 8.1398e-04
# Epoch 6/25
# 113/113 - 0s - 3ms/step - loss: 7.5704e-04
# Epoch 7/25
# 113/113 - 0s - 2ms/step - loss: 6.9963e-04
# Epoch 8/25
# 113/113 - 0s - 3ms/step - loss: 7.0500e-04
# Epoch 9/25
# 113/113 - 0s - 2ms/step - loss: 6.5757e-04
# Epoch 10/25
# 113/113 - 0s - 3ms/step - loss: 6.0688e-04
# Epoch 11/25
# 113/113 - 0s - 2ms/step - loss: 5.9885e-04
# Epoch 12/25
# 113/113 - 0s - 2ms/step - loss: 6.2562e-04
# Epoch 13/25
# 113/113 - 0s - 2ms/step - loss: 5.4839e-04
# Epoch 14/25
# 113/113 - 0s - 3ms/step - loss: 5.6678e-04
# Epoch 15/25
# 113/113 - 0s - 4ms/step - loss: 5.6843e-04
# Epoch 16/25
# 113/113 - 1s - 5ms/step - loss: 5.1082e-04
# Epoch 17/25
# 113/113 - 1s - 5ms/step - loss: 5.2351e-04
# Epoch 18/25
# 113/113 - 0s - 4ms/step - loss: 4.6538e-04
# Epoch 19/25
# 113/113 - 1s - 6ms/step - loss: 5.0523e-04
# Epoch 20/25
# 113/113 - 0s - 4ms/step - loss: 4.7318e-04
# Epoch 21/25
# 113/113 - 0s - 4ms/step - loss: 4.0985e-04
# Epoch 22/25
# 113/113 - 0s - 2ms/step - loss: 4.4251e-04
# Epoch 23/25
# 113/113 - 0s - 2ms/step - loss: 4.0636e-04
# Epoch 24/25
# 113/113 - 0s - 3ms/step - loss: 4.1445e-04
# Epoch 25/25
# 113/113 - 0s - 2ms/step - loss: 4.1026e-04
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Processing PNB.NS...
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 280/280 - 2s - 8ms/step - loss: 0.0153
# Epoch 2/25
# 280/280 - 1s - 2ms/step - loss: 0.0011
# Epoch 3/25
# 280/280 - 1s - 2ms/step - loss: 8.8456e-04
# Epoch 4/25
# 280/280 - 1s - 2ms/step - loss: 8.0449e-04
# Epoch 5/25
# 280/280 - 1s - 2ms/step - loss: 7.6430e-04
# Epoch 6/25
# 280/280 - 1s - 4ms/step - loss: 7.0195e-04
# Epoch 7/25
# 280/280 - 1s - 3ms/step - loss: 6.8044e-04
# Epoch 8/25
# 280/280 - 1s - 5ms/step - loss: 5.9663e-04
# Epoch 9/25
# 280/280 - 1s - 4ms/step - loss: 5.7160e-04
# Epoch 10/25
# 280/280 - 1s - 3ms/step - loss: 5.1327e-04
# Epoch 11/25
# 280/280 - 1s - 2ms/step - loss: 4.9791e-04
# Epoch 12/25
# 280/280 - 1s - 2ms/step - loss: 4.5834e-04
# Epoch 13/25
# 280/280 - 1s - 2ms/step - loss: 4.5515e-04
# Epoch 14/25
# 280/280 - 1s - 2ms/step - loss: 4.2616e-04
# Epoch 15/25
# 280/280 - 1s - 2ms/step - loss: 3.8621e-04
# Epoch 16/25
# 280/280 - 1s - 2ms/step - loss: 3.7856e-04
# Epoch 17/25
# 280/280 - 1s - 2ms/step - loss: 3.7293e-04
# Epoch 18/25
# 280/280 - 1s - 2ms/step - loss: 3.4662e-04
# Epoch 19/25
# 280/280 - 1s - 5ms/step - loss: 3.2430e-04
# Epoch 20/25
# 280/280 - 1s - 2ms/step - loss: 3.1179e-04
# Epoch 21/25
# 280/280 - 1s - 4ms/step - loss: 2.9175e-04
# Epoch 22/25
# 280/280 - 1s - 4ms/step - loss: 2.7426e-04
# Epoch 23/25
# 280/280 - 2s - 6ms/step - loss: 2.6291e-04
# Epoch 24/25
# 280/280 - 1s - 5ms/step - loss: 2.7928e-04
# Epoch 25/25
# 280/280 - 1s - 4ms/step - loss: 2.5917e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Processing BANKBARODA.NS...
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/25
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 280/280 - 2s - 8ms/step - loss: 0.0089
# Epoch 2/25
# 280/280 - 1s - 2ms/step - loss: 7.4229e-04
# Epoch 3/25
# 280/280 - 1s - 2ms/step - loss: 6.3498e-04
# Epoch 4/25
# 280/280 - 1s - 2ms/step - loss: 5.5816e-04
# Epoch 5/25
# 280/280 - 1s - 2ms/step - loss: 5.1969e-04
# Epoch 6/25
# 280/280 - 1s - 2ms/step - loss: 4.7548e-04
# Epoch 7/25
# 280/280 - 1s - 2ms/step - loss: 4.3155e-04
# Epoch 8/25
# 280/280 - 1s - 2ms/step - loss: 3.9730e-04
# Epoch 9/25
# 280/280 - 1s - 2ms/step - loss: 3.6753e-04
# Epoch 10/25
# 280/280 - 1s - 2ms/step - loss: 3.7089e-04
# Epoch 11/25
# 280/280 - 1s - 3ms/step - loss: 3.3603e-04
# Epoch 12/25
# 280/280 - 1s - 5ms/step - loss: 3.2681e-04
# Epoch 13/25
# 280/280 - 1s - 3ms/step - loss: 2.9791e-04
# Epoch 14/25
# 280/280 - 1s - 3ms/step - loss: 2.8398e-04
# Epoch 15/25
# 280/280 - 1s - 2ms/step - loss: 2.5315e-04
# Epoch 16/25
# 280/280 - 1s - 2ms/step - loss: 2.4910e-04
# Epoch 17/25
# 280/280 - 1s - 2ms/step - loss: 2.3768e-04
# Epoch 18/25
# 280/280 - 1s - 4ms/step - loss: 2.3121e-04
# Epoch 19/25
# 280/280 - 1s - 2ms/step - loss: 2.0541e-04
# Epoch 20/25
# 280/280 - 1s - 2ms/step - loss: 2.0944e-04
# Epoch 21/25
# 280/280 - 1s - 2ms/step - loss: 2.0847e-04
# Epoch 22/25
# 280/280 - 1s - 2ms/step - loss: 2.0325e-04
# Epoch 23/25
# 280/280 - 1s - 2ms/step - loss: 1.8709e-04
# Epoch 24/25
# 280/280 - 1s - 2ms/step - loss: 1.8937e-04
# Epoch 25/25
# 280/280 - 1s - 2ms/step - loss: 1.7523e-04
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#           Symbol  Predicted Close Price  Accuracy (%)       MSE  R-squared
# 0   ICICIBANK.NS            1282.241577     99.797500  0.000069   0.997975
# 1    AXISBANK.NS            1060.937622     99.286198  0.000218   0.992862
# 2        SBIN.NS             786.451416     99.676879  0.000154   0.996769
# 3  INDUSINDBK.NS             974.923279     99.318809  0.000126   0.993188
# 4  FEDERALBNK.NS             206.046356     99.729211  0.000113   0.997292
# 5  IDFCFIRSTB.NS              64.605865     98.801742  0.000197   0.988017
# 6         PNB.NS             104.590775     99.829499  0.000025   0.998295
# 7  BANKBARODA.NS             240.129944     99.840627  0.000105   0.998406

# %% [markdown]
# LINEAR REGRESSION

# %%
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Function to retrieve data for a given symbol with only open and close prices
def get_stock_data(symbol, start_date, end_date):
    try:
        data = yf.download(symbol, start=start_date, end=end_date)[['Open', 'Close']]
        return data
    except Exception as e:
        print(f"Failed to download data for {symbol}: {e}")
        return None

# Function to preprocess data and split into training and testing sets
def preprocess_data(data, train_percentage=0.8):
    if data is None or data.empty:
        return None, None, None

    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data)

    train_size = int(len(scaled_data) * train_percentage)
    if train_size == 0:
        return None, None, None

    train_data = scaled_data[:train_size]
    test_data = scaled_data[train_size:]

    return train_data, test_data, scaler

# Function to train Linear Regression model
def train_linear_regression_model(X_train, y_train):
    model = LinearRegression()
    model.fit(X_train, y_train)
    return model

# Function to evaluate model performance
def evaluate_model(y_true, y_pred):
    mse = mean_squared_error(y_true, y_pred)
    accuracy = r2_score(y_true, y_pred)
    return mse, accuracy

# Function to plot predicted vs actual prices for a stock
def plot_predictions(symbol, actual_prices, predicted_prices, dates, scaler):
    actual_prices = scaler.inverse_transform(actual_prices)
    predicted_prices = scaler.inverse_transform(predicted_prices)

    plt.figure(figsize=(16, 8))
    plt.plot(dates, actual_prices[:, 1], label='Actual Close Prices')
    plt.plot(dates, predicted_prices[:, 1], label='Predicted Close Prices')
    plt.title(f"Actual vs Predicted Close Prices for {symbol}")
    plt.xlabel("Date")
    plt.ylabel("Close Price (INR)")
    plt.xticks(rotation=45)
    plt.legend()
    plt.show()

# Main function with further refined settings for improved accuracy
def main():
    symbols =  ['ICICIBANK.NS', 'AXISBANK.NS', 'SBIN.NS', 'INDUSINDBK.NS', 'FEDERALBNK.NS', 'IDFCFIRSTB.NS', 'PNB.NS', 'BANKBARODA.NS']
    end_date = input("Enter end date (YYYY-MM-DD): ")
    end_date_dt = pd.to_datetime(end_date)
    start_date_dt = pd.to_datetime('2000-01-01')

    results = []

    for symbol in symbols:
        print(f"Processing {symbol}...")
        data = get_stock_data(symbol, start_date=start_date_dt, end_date=end_date)
        if data is None:
            print(f"No data available for {symbol}. Skipping...")
            continue

        train_data, test_data, scaler = preprocess_data(data)
        if train_data is None or test_data is None or scaler is None:
            print(f"Insufficient data for {symbol}. Skipping...")
            continue

        X_train, y_train = train_data[:-1], train_data[1:]
        X_test, y_test = test_data[:-1], test_data[1:]

        model = train_linear_regression_model(X_train, y_train)

        predictions = model.predict(X_test)

        mse, accuracy = evaluate_model(y_test, predictions)

        dates = data.index[-len(predictions):]  # Dates for the test data

        plot_predictions(symbol, test_data[1:], predictions, dates, scaler)

        results.append({
            'Symbol': symbol,
            'Predicted Close Price': scaler.inverse_transform(predictions)[-1][1],
            'Accuracy (%)': accuracy * 100,
            'MSE': mse,
            'R-squared': accuracy
        })
    if results:
        results_df = pd.DataFrame(results)
        print(results_df)

if __name__ == "__main__":
    main()
# Out:
# Enter end date (YYYY-MM-DD): 2025-05-23
# Processing ICICIBANK.NS...
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Processing AXISBANK.NS...
# [*********************100%***********************]  1 of 1 completed
# Processing SBIN.NS...
# [*********************100%***********************]  1 of 1 completed
# Processing INDUSINDBK.NS...
# [*********************100%***********************]  1 of 1 completed
# Processing FEDERALBNK.NS...
# [*********************100%***********************]  1 of 1 completed
# Processing IDFCFIRSTB.NS...
# [*********************100%***********************]  1 of 1 completed
# Processing PNB.NS...
# [*********************100%***********************]  1 of 1 completed
# Processing BANKBARODA.NS...
# [*********************100%***********************]  1 of 1 completed
#           Symbol  Predicted Close Price  Accuracy (%)       MSE  R-squared
# 0   ICICIBANK.NS            1443.980421     99.832210  0.000050   0.998322
# 1    AXISBANK.NS            1197.362209     99.751175  0.000077   0.997512
# 2        SBIN.NS             786.548138     99.864726  0.000067   0.998647
# 3  INDUSINDBK.NS             769.444930     99.437511  0.000091   0.994375
# 4  FEDERALBNK.NS             200.771135     99.857474  0.000070   0.998575
# 5  IDFCFIRSTB.NS              66.596156     99.045947  0.000163   0.990459
# 6         PNB.NS             102.013694     99.849970  0.000032   0.998500
# 7  BANKBARODA.NS             241.086189     99.839019  0.000104   0.998390
